# %% [markdown]
# <h2>Pandas Series

# %% [markdown]
# Importing pandas & declaring variables labels, data & dataCorrelated

# %%
import pandas as pd

labels = ['a', 'b', 'c', 'd']

data = ['25', '50', '75', '100']

dataCorrelated = {'a': 100, 'b': 200, 'c': 300, 'd': 400}

# %%
pd.Series(data, index=labels)
# Out:
# a     25
# b     50
# c     75
# d    100
# dtype: object

# %%
pd.Series(dataCorrelated, index=labels)
# Out:
# a    100
# b    200
# c    300
# d    400
# dtype: int64

# %% [markdown]
# <h4>Applying Math to Pandas Series & Dataframes

# %%
#Why Doesnt this work?
series1 = pd.Series(data, index=labels)

series2 = pd.Series(dataCorrelated, index=labels)

series1 + series2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/UdemyTutorial/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# ~/UdemyTutorial/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~/UdemyTutorial/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      67     with np.errstate(all='ignore'):
# ---> 68         return op(a, b)
#      69
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/UdemyTutorial/lib/python3.7/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#    1528             with np.errstate(all='ignore'):
# -> 1529                 return na_op(lvalues, rvalues)
#    1530         except Exception:
#
# ~/UdemyTutorial/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1506         except TypeError:
# -> 1507             result = masked_arith_op(x, y, op)
#    1508
#
# ~/UdemyTutorial/lib/python3.7/site-packages/pandas/core/ops.py in masked_arith_op(x, y, op)
#    1008                 result[mask] = op(xrav[mask],
# -> 1009                                   com.values_from_object(yrav[mask]))
#    1010
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-749a63b4a47e> in <module>
#       4 series2 = pd.Series(dataCorrelated, index=labels)
#       5
# ----> 6 series1 + series2
#       7
#
# ~/UdemyTutorial/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(left, right)
#    1581             rvalues = rvalues.values
#    1582
# -> 1583         result = safe_na_op(lvalues, rvalues)
#    1584         return construct_result(left, result,
#    1585                                 index=left.index, name=res_name, dtype=None)
#
# ~/UdemyTutorial/lib/python3.7/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#    1531             if is_object_dtype(lvalues):
#    1532                 return libalgos.arrmap_object(lvalues,
# -> 1533                                               lambda x: op(x, rvalues))
#    1534             raise
#    1535
#
# pandas/_libs/algos.pyx in pandas._libs.algos.arrmap()
#
# ~/UdemyTutorial/lib/python3.7/site-packages/pandas/core/ops.py in <lambda>(x)
#    1531             if is_object_dtype(lvalues):
#    1532                 return libalgos.arrmap_object(lvalues,
# -> 1533                                               lambda x: op(x, rvalues))
#    1534             raise
#    1535
#
# TypeError: ufunc 'add' did not contain a loop with signature matching types dtype('<U21') dtype('<U21') dtype('<U21')

# %% [markdown]
# How to change the data's dtype:

# %%
series1.astype(int) + series2
# Out:
# a    125
# b    250
# c    375
# d    500
# dtype: int64

# %%
series1.astype(float) + series2
# Out:
# a    125.0
# b    250.0
# c    375.0
# d    500.0
# dtype: float64

# %%
series1 + series2.astype(str)
# Out:
# a     25100
# b     50200
# c     75300
# d    100400
# dtype: object
